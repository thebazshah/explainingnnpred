# %%
# python notebook for Make Your Own Neural Network
# (c) Tariq Rashid, 2016
# license is GPLv2

# %%
import numpy as np
# scipy.special for the sigmoid function expit()
import scipy.special as special
import matplotlib.pyplot as plt

# %%
# neural network class definition
class neuralNetwork:
    
    
    # initialise the neural network
    def __init__(self, inputnodes, hiddennodes, outputnodes, learningrate):
        # set number of nodes in each input, hidden, output layer
        self.inodes = inputnodes
        self.hnodes = hiddennodes
        self.onodes = outputnodes
        
        # link weight matrices, wih and who
        # weights inside the arrays are w_i_j, where link is from node i to node j in the next layer
        # w11 w21
        # w12 w22 etc 
        self.wih = np.random.normal(0.0, pow(self.hnodes, -0.5), (self.hnodes, self.inodes))
        self.who = np.random.normal(0.0, pow(self.onodes, -0.5), (self.onodes, self.hnodes))

        # learning rate
        self.lr = learningrate
        
        # activation function is the sigmoid function
        self.activation_function = lambda x: special.expit(x)
        
        pass

    
    # train the neural network
    def train(self, inputs_list, targets_list):
        # convert inputs list to 2d array
        inputs = np.array(inputs_list, ndmin=2).T
        targets = np.array(targets_list, ndmin=2).T
        
        # calculate signals into hidden layer
        hidden_inputs = np.dot(self.wih, inputs)
        # calculate the signals emerging from hidden layer
        hidden_outputs = self.activation_function(hidden_inputs)
        
        # calculate signals into final output layer
        final_inputs = np.dot(self.who, hidden_outputs)
        # calculate the signals emerging from final output layer
        final_outputs = self.activation_function(final_inputs)
        
        # output layer error is the (target - actual)
        output_errors = targets - final_outputs
        # hidden layer error is the output_errors, split by weights, recombined at hidden nodes
        hidden_errors = np.dot(self.who.T, output_errors) 
        
        # update the weights for the links between the hidden and output layers
        self.who += self.lr * np.dot((output_errors * final_outputs * (1.0 - final_outputs)), np.transpose(hidden_outputs))
        
        # update the weights for the links between the input and hidden layers
        self.wih += self.lr * np.dot((hidden_errors * hidden_outputs * (1.0 - hidden_outputs)), np.transpose(inputs))
        
        print("Output errors:", output_errors)
        pass

    
    # query the neural network
    def query(self, inputs_list):
        # convert inputs list to 2d array
        inputs = np.array(inputs_list, ndmin=2).T
        
        # calculate signals into hidden layer
        hidden_inputs = np.dot(self.wih, inputs)
        # calculate the signals emerging from hidden layer
        hidden_outputs = self.activation_function(hidden_inputs)
        
        # calculate signals into final output layer
        final_inputs = np.dot(self.who, hidden_outputs)
        # calculate the signals emerging from final output layer
        final_outputs = self.activation_function(final_inputs)
        
        return final_outputs

# %%
# number of input, hidden and output nodes
input_nodes = 4
hidden_nodes = 4
output_nodes = 1

# learning rate is 0.3
learning_rate = 0.3

# create instance of neural network
n = neuralNetwork(input_nodes,hidden_nodes,output_nodes, learning_rate)

# %%
data = [[0.645569620253164, 0.795454545454545, 0.202898550724638, 0.08, 0.333333333333333],
[0.620253164556962, 0.681818181818182, 0.202898550724638, 0.08, 0.333333333333333],
[0.594936708860759, 0.727272727272727, 0.188405797101449, 0.08, 0.333333333333333],
[0.582278481012658, 0.704545454545454, 0.217391304347826, 0.08, 0.333333333333333],
[0.632911392405063, 0.818181818181818, 0.202898550724638, 0.08, 0.333333333333333],
[0.683544303797468, 0.886363636363636, 0.246376811594203, 0.16, 0.333333333333333],
[0.582278481012658, 0.772727272727273, 0.202898550724638, 0.12, 0.333333333333333],
[0.632911392405063, 0.772727272727273, 0.217391304347826, 0.08, 0.333333333333333],
[0.556962025316456, 0.659090909090909, 0.202898550724638, 0.08, 0.333333333333333],
[0.620253164556962, 0.704545454545454, 0.217391304347826, 0.04, 0.333333333333333],
[0.683544303797468, 0.840909090909091, 0.217391304347826, 0.08, 0.333333333333333],
[0.607594936708861, 0.772727272727273, 0.231884057971014, 0.08, 0.333333333333333],
[0.607594936708861, 0.681818181818182, 0.202898550724638, 0.04, 0.333333333333333],
[0.544303797468354, 0.681818181818182, 0.159420289855072, 0.04, 0.333333333333333],
[0.734177215189873, 0.909090909090909, 0.173913043478261, 0.08, 0.333333333333333],
[0.721518987341772, 1, 0.217391304347826, 0.16, 0.333333333333333],
[0.683544303797468, 0.886363636363636, 0.188405797101449, 0.16, 0.333333333333333],
[0.645569620253164, 0.795454545454545, 0.202898550724638, 0.12, 0.333333333333333],
[0.721518987341772, 0.863636363636364, 0.246376811594203, 0.12, 0.333333333333333],
[0.645569620253164, 0.863636363636364, 0.217391304347826, 0.12, 0.333333333333333],
[0.683544303797468, 0.772727272727273, 0.246376811594203, 0.08, 0.333333333333333],
[0.645569620253164, 0.840909090909091, 0.217391304347826, 0.16, 0.333333333333333],
[0.582278481012658, 0.818181818181818, 0.144927536231884, 0.08, 0.333333333333333],
[0.645569620253164, 0.75, 0.246376811594203, 0.2, 0.333333333333333],
[0.607594936708861, 0.772727272727273, 0.27536231884058, 0.08, 0.333333333333333],
[0.632911392405063, 0.681818181818182, 0.231884057971014, 0.08, 0.333333333333333],
[0.632911392405063, 0.772727272727273, 0.231884057971014, 0.16, 0.333333333333333],
[0.658227848101266, 0.795454545454545, 0.217391304347826, 0.08, 0.333333333333333],
[0.658227848101266, 0.772727272727273, 0.202898550724638, 0.08, 0.333333333333333],
[0.594936708860759, 0.727272727272727, 0.231884057971014, 0.08, 0.333333333333333],
[0.607594936708861, 0.704545454545454, 0.231884057971014, 0.08, 0.333333333333333],
[0.683544303797468, 0.772727272727273, 0.217391304347826, 0.16, 0.333333333333333],
[0.658227848101266, 0.931818181818182, 0.217391304347826, 0.04, 0.333333333333333],
[0.69620253164557, 0.954545454545454, 0.202898550724638, 0.08, 0.333333333333333],
[0.620253164556962, 0.704545454545454, 0.217391304347826, 0.04, 0.333333333333333],
[0.632911392405063, 0.727272727272727, 0.173913043478261, 0.08, 0.333333333333333],
[0.69620253164557, 0.795454545454545, 0.188405797101449, 0.08, 0.333333333333333],
[0.620253164556962, 0.704545454545454, 0.217391304347826, 0.04, 0.333333333333333],
[0.556962025316456, 0.681818181818182, 0.188405797101449, 0.08, 0.333333333333333],
[0.645569620253164, 0.772727272727273, 0.217391304347826, 0.08, 0.333333333333333],
[0.632911392405063, 0.795454545454545, 0.188405797101449, 0.12, 0.333333333333333],
[0.569620253164557, 0.522727272727273, 0.188405797101449, 0.12, 0.333333333333333],
[0.556962025316456, 0.727272727272727, 0.188405797101449, 0.08, 0.333333333333333],
[0.632911392405063, 0.795454545454545, 0.231884057971014, 0.24, 0.333333333333333],
[0.645569620253164, 0.863636363636364, 0.27536231884058, 0.16, 0.333333333333333],
[0.607594936708861, 0.681818181818182, 0.202898550724638, 0.12, 0.333333333333333],
[0.645569620253164, 0.863636363636364, 0.231884057971014, 0.08, 0.333333333333333],
[0.582278481012658, 0.727272727272727, 0.202898550724638, 0.08, 0.333333333333333],
[0.670886075949367, 0.840909090909091, 0.217391304347826, 0.08, 0.333333333333333],
[0.632911392405063, 0.75, 0.202898550724638, 0.08, 0.333333333333333],
[0.886075949367089, 0.727272727272727, 0.681159420289855, 0.56, 0.666666666666667],
[0.810126582278481, 0.727272727272727, 0.652173913043478, 0.6, 0.666666666666667],
[0.873417721518987, 0.704545454545454, 0.710144927536232, 0.6, 0.666666666666667],
[0.69620253164557, 0.522727272727273, 0.579710144927536, 0.52, 0.666666666666667],
[0.822784810126582, 0.636363636363636, 0.666666666666667, 0.6, 0.666666666666667],
[0.721518987341772, 0.636363636363636, 0.652173913043478, 0.52, 0.666666666666667],
[0.79746835443038, 0.75, 0.681159420289855, 0.64, 0.666666666666667],
[0.620253164556962, 0.545454545454545, 0.478260869565217, 0.4, 0.666666666666667],
[0.835443037974683, 0.659090909090909, 0.666666666666667, 0.52, 0.666666666666667],
[0.658227848101266, 0.613636363636364, 0.565217391304348, 0.56, 0.666666666666667],
[0.632911392405063, 0.454545454545455, 0.507246376811594, 0.4, 0.666666666666667],
[0.746835443037975, 0.681818181818182, 0.608695652173913, 0.6, 0.666666666666667],
[0.759493670886076, 0.5, 0.579710144927536, 0.4, 0.666666666666667],
[0.772151898734177, 0.659090909090909, 0.681159420289855, 0.56, 0.666666666666667],
[0.708860759493671, 0.659090909090909, 0.521739130434783, 0.52, 0.666666666666667],
[0.848101265822785, 0.704545454545454, 0.63768115942029, 0.56, 0.666666666666667],
[0.708860759493671, 0.681818181818182, 0.652173913043478, 0.6, 0.666666666666667],
[0.734177215189873, 0.613636363636364, 0.594202898550725, 0.4, 0.666666666666667],
[0.784810126582278, 0.5, 0.652173913043478, 0.6, 0.666666666666667],
[0.708860759493671, 0.568181818181818, 0.565217391304348, 0.44, 0.666666666666667],
[0.746835443037975, 0.727272727272727, 0.695652173913043, 0.72, 0.666666666666667],
[0.772151898734177, 0.636363636363636, 0.579710144927536, 0.52, 0.666666666666667],
[0.79746835443038, 0.568181818181818, 0.710144927536232, 0.6, 0.666666666666667],
[0.772151898734177, 0.636363636363636, 0.681159420289855, 0.48, 0.666666666666667],
[0.810126582278481, 0.659090909090909, 0.623188405797101, 0.52, 0.666666666666667],
[0.835443037974683, 0.681818181818182, 0.63768115942029, 0.56, 0.666666666666667],
[0.860759493670886, 0.636363636363636, 0.695652173913043, 0.56, 0.666666666666667],
[0.848101265822785, 0.681818181818182, 0.72463768115942, 0.68, 0.666666666666667],
[0.759493670886076, 0.659090909090909, 0.652173913043478, 0.6, 0.666666666666667],
[0.721518987341772, 0.590909090909091, 0.507246376811594, 0.4, 0.666666666666667],
[0.69620253164557, 0.545454545454545, 0.550724637681159, 0.44, 0.666666666666667],
[0.69620253164557, 0.545454545454545, 0.536231884057971, 0.4, 0.666666666666667],
[0.734177215189873, 0.613636363636364, 0.565217391304348, 0.48, 0.666666666666667],
[0.759493670886076, 0.613636363636364, 0.739130434782609, 0.64, 0.666666666666667],
[0.683544303797468, 0.681818181818182, 0.652173913043478, 0.6, 0.666666666666667],
[0.759493670886076, 0.772727272727273, 0.652173913043478, 0.64, 0.666666666666667],
[0.848101265822785, 0.704545454545454, 0.681159420289855, 0.6, 0.666666666666667],
[0.79746835443038, 0.522727272727273, 0.63768115942029, 0.52, 0.666666666666667],
[0.708860759493671, 0.681818181818182, 0.594202898550725, 0.52, 0.666666666666667],
[0.69620253164557, 0.568181818181818, 0.579710144927536, 0.52, 0.666666666666667],
[0.69620253164557, 0.590909090909091, 0.63768115942029, 0.48, 0.666666666666667],
[0.772151898734177, 0.681818181818182, 0.666666666666667, 0.56, 0.666666666666667],
[0.734177215189873, 0.590909090909091, 0.579710144927536, 0.48, 0.666666666666667],
[0.632911392405063, 0.522727272727273, 0.478260869565217, 0.4, 0.666666666666667],
[0.708860759493671, 0.613636363636364, 0.608695652173913, 0.52, 0.666666666666667],
[0.721518987341772, 0.681818181818182, 0.608695652173913, 0.48, 0.666666666666667],
[0.721518987341772, 0.659090909090909, 0.608695652173913, 0.52, 0.666666666666667],
[0.784810126582278, 0.659090909090909, 0.623188405797101, 0.52, 0.666666666666667],
[0.645569620253164, 0.568181818181818, 0.434782608695652, 0.44, 0.666666666666667],
[0.721518987341772, 0.636363636363636, 0.594202898550725, 0.52, 0.666666666666667],
[0.79746835443038, 0.75, 0.869565217391304, 1, 1],
[0.734177215189873, 0.613636363636364, 0.739130434782609, 0.76, 1],
[0.89873417721519, 0.681818181818182, 0.855072463768116, 0.84, 1],
[0.79746835443038, 0.659090909090909, 0.811594202898551, 0.72, 1],
[0.822784810126582, 0.681818181818182, 0.840579710144927, 0.88, 1],
[0.962025316455696, 0.681818181818182, 0.956521739130435, 0.84, 1],
[0.620253164556962, 0.568181818181818, 0.652173913043478, 0.68, 1],
[0.924050632911392, 0.659090909090909, 0.91304347826087, 0.72, 1],
[0.848101265822785, 0.568181818181818, 0.840579710144927, 0.72, 1],
[0.911392405063291, 0.818181818181818, 0.884057971014493, 1, 1],
[0.822784810126582, 0.727272727272727, 0.739130434782609, 0.8, 1],
[0.810126582278481, 0.613636363636364, 0.768115942028985, 0.76, 1],
[0.860759493670886, 0.681818181818182, 0.797101449275362, 0.84, 1],
[0.721518987341772, 0.568181818181818, 0.72463768115942, 0.8, 1],
[0.734177215189873, 0.636363636363636, 0.739130434782609, 0.96, 1],
[0.810126582278481, 0.727272727272727, 0.768115942028985, 0.92, 1],
[0.822784810126582, 0.681818181818182, 0.797101449275362, 0.72, 1],
[0.974683544303797, 0.863636363636364, 0.971014492753623, 0.88, 1],
[0.974683544303797, 0.590909090909091, 1, 0.92, 1],
[0.759493670886076, 0.5, 0.72463768115942, 0.6, 1],
[0.873417721518987, 0.727272727272727, 0.826086956521739, 0.92, 1],
[0.708860759493671, 0.636363636363636, 0.710144927536232, 0.8, 1],
[0.974683544303797, 0.636363636363636, 0.971014492753623, 0.8, 1],
[0.79746835443038, 0.613636363636364, 0.710144927536232, 0.72, 1],
[0.848101265822785, 0.75, 0.826086956521739, 0.84, 1],
[0.911392405063291, 0.727272727272727, 0.869565217391304, 0.72, 1],
[0.784810126582278, 0.636363636363636, 0.695652173913043, 0.72, 1],
[0.772151898734177, 0.681818181818182, 0.710144927536232, 0.72, 1],
[0.810126582278481, 0.636363636363636, 0.811594202898551, 0.84, 1],
[0.911392405063291, 0.681818181818182, 0.840579710144927, 0.64, 1],
[0.936708860759494, 0.636363636363636, 0.884057971014493, 0.76, 1],
[1, 0.863636363636364, 0.927536231884058, 0.8, 1],
[0.810126582278481, 0.636363636363636, 0.811594202898551, 0.88, 1],
[0.79746835443038, 0.636363636363636, 0.739130434782609, 0.6, 1],
[0.772151898734177, 0.590909090909091, 0.811594202898551, 0.56, 1],
[0.974683544303797, 0.681818181818182, 0.884057971014493, 0.92, 1],
[0.79746835443038, 0.772727272727273, 0.811594202898551, 0.96, 1],
[0.810126582278481, 0.704545454545454, 0.797101449275362, 0.72, 1],
[0.759493670886076, 0.681818181818182, 0.695652173913043, 0.72, 1],
[0.873417721518987, 0.704545454545454, 0.782608695652174, 0.84, 1],
[0.848101265822785, 0.704545454545454, 0.811594202898551, 0.96, 1],
[0.873417721518987, 0.704545454545454, 0.739130434782609, 0.92, 1],
[0.734177215189873, 0.613636363636364, 0.739130434782609, 0.76, 1],
[0.860759493670886, 0.727272727272727, 0.855072463768116, 0.92, 1],
[0.848101265822785, 0.75, 0.826086956521739, 1, 1],
[0.848101265822785, 0.681818181818182, 0.753623188405797, 0.92, 1],
[0.79746835443038, 0.568181818181818, 0.72463768115942, 0.76, 1],
[0.822784810126582, 0.681818181818182, 0.753623188405797, 0.8, 1],
[0.784810126582278, 0.772727272727273, 0.782608695652174, 0.92, 1],
[0.746835443037975, 0.681818181818182, 0.739130434782609, 0.72, 1]]

# %%
weight_changes = []
count = 1
iterations = []
for i in data:
    n.train(i[0:4], i[4:5])
    weights = np.copy(n.who)
    weight_changes.append(weights)
    iterations.append(count)
# Out:
# Output errors: [[-0.1127877]]
# Output errors: [[-0.11878707]]
# Output errors: [[-0.11494972]]
# Output errors: [[-0.11527927]]
# Output errors: [[-0.09790195]]
# Output errors: [[-0.07953676]]
# Output errors: [[-0.09763863]]
# Output errors: [[-0.09214371]]
# Output errors: [[-0.1059215]]
# Output errors: [[-0.09546073]]
# Output errors: [[-0.07255627]]
# Output errors: [[-0.08415925]]
# Output errors: [[-0.09036809]]
# Output errors: [[-0.09459309]]
# Output errors: [[-0.05080776]]
# Output errors: [[-0.04064061]]
# Output errors: [[-0.04936752]]
# Output errors: [[-0.06134103]]
# Output errors: [[-0.04738426]]
# Output errors: [[-0.05386386]]
# Output errors: [[-0.05756377]]
# Output errors: [[-0.04892718]]
# Output errors: [[-0.06086535]]
# Output errors: [[-0.04939956]]
# Output errors: [[-0.06099933]]
# Output errors: [[-0.06160046]]
# Output errors: [[-0.04700348]]
# Output errors: [[-0.04672876]]
# Output errors: [[-0.04660514]]
# Output errors: [[-0.0570932]]
# Output errors: [[-0.05557539]]
# Output errors: [[-0.03344018]]
# Output errors: [[-0.03316488]]
# Output errors: [[-0.02333948]]
# Output errors: [[-0.05257918]]
# Output errors: [[-0.04360479]]
# Output errors: [[-0.03020745]]
# Output errors: [[-0.04897533]]
# Output errors: [[-0.05369901]]
# Output errors: [[-0.0346841]]
# Output errors: [[-0.03000074]]
# Output errors: [[-0.05885668]]
# Output errors: [[-0.04518869]]
# Output errors: [[-0.01887125]]
# Output errors: [[-0.01848339]]
# Output errors: [[-0.03735149]]
# Output errors: [[-0.02160815]]
# Output errors: [[-0.0383657]]
# Output errors: [[-0.0183535]]
# Output errors: [[-0.02873536]]
# Output errors: [[ 0.35319147]]
# Output errors: [[ 0.33870734]]
# Output errors: [[ 0.33234967]]
# Output errors: [[ 0.28934319]]
# Output errors: [[ 0.30475952]]
# Output errors: [[ 0.27874987]]
# Output errors: [[ 0.29095857]]
# Output errors: [[ 0.23904503]]
# Output errors: [[ 0.26416827]]
# Output errors: [[ 0.23860919]]
# Output errors: [[ 0.20831677]]
# Output errors: [[ 0.2376216]]
# Output errors: [[ 0.20720063]]
# Output errors: [[ 0.21585833]]
# Output errors: [[ 0.20625493]]
# Output errors: [[ 0.21159255]]
# Output errors: [[ 0.18834774]]
# Output errors: [[ 0.17030459]]
# Output errors: [[ 0.17209762]]
# Output errors: [[ 0.15614531]]
# Output errors: [[ 0.16991179]]
# Output errors: [[ 0.15658166]]
# Output errors: [[ 0.14451081]]
# Output errors: [[ 0.13342891]]
# Output errors: [[ 0.13908236]]
# Output errors: [[ 0.13732448]]
# Output errors: [[ 0.12667665]]
# Output errors: [[ 0.12548217]]
# Output errors: [[ 0.11186326]]
# Output errors: [[ 0.10220767]]
# Output errors: [[ 0.09263815]]
# Output errors: [[ 0.08812554]]
# Output errors: [[ 0.09231535]]
# Output errors: [[ 0.08334907]]
# Output errors: [[ 0.08101501]]
# Output errors: [[ 0.08857978]]
# Output errors: [[ 0.08462477]]
# Output errors: [[ 0.07080053]]
# Output errors: [[ 0.06951195]]
# Output errors: [[ 0.06363546]]
# Output errors: [[ 0.0539653]]
# Output errors: [[ 0.06126337]]
# Output errors: [[ 0.05771179]]
# Output errors: [[ 0.05203096]]
# Output errors: [[ 0.05105419]]
# Output errors: [[ 0.04963274]]
# Output errors: [[ 0.04881088]]
# Output errors: [[ 0.04985819]]
# Output errors: [[ 0.05089073]]
# Output errors: [[ 0.04345471]]
# Output errors: [[ 0.37639971]]
# Output errors: [[ 0.3503473]]
# Output errors: [[ 0.3337333]]
# Output errors: [[ 0.30959709]]
# Output errors: [[ 0.29628516]]
# Output errors: [[ 0.27179681]]
# Output errors: [[ 0.27583262]]
# Output errors: [[ 0.24612103]]
# Output errors: [[ 0.24070528]]
# Output errors: [[ 0.22864473]]
# Output errors: [[ 0.23006243]]
# Output errors: [[ 0.21807647]]
# Output errors: [[ 0.20695028]]
# Output errors: [[ 0.20656516]]
# Output errors: [[ 0.19721669]]
# Output errors: [[ 0.18650534]]
# Output errors: [[ 0.17888654]]
# Output errors: [[ 0.15535053]]
# Output errors: [[ 0.15205168]]
# Output errors: [[ 0.17574869]]
# Output errors: [[ 0.1551775]]
# Output errors: [[ 0.1639773]]
# Output errors: [[ 0.13827268]]
# Output errors: [[ 0.1577937]]
# Output errors: [[ 0.14020731]]
# Output errors: [[ 0.13536322]]
# Output errors: [[ 0.14873012]]
# Output errors: [[ 0.14337531]]
# Output errors: [[ 0.13178959]]
# Output errors: [[ 0.12834328]]
# Output errors: [[ 0.12235478]]
# Output errors: [[ 0.11288747]]
# Output errors: [[ 0.12238358]]
# Output errors: [[ 0.12945984]]
# Output errors: [[ 0.12389603]]
# Output errors: [[ 0.10963702]]
# Output errors: [[ 0.11113777]]
# Output errors: [[ 0.11470991]]
# Output errors: [[ 0.12080073]]
# Output errors: [[ 0.11012546]]
# Output errors: [[ 0.10551708]]
# Output errors: [[ 0.10861328]]
# Output errors: [[ 0.11255534]]
# Output errors: [[ 0.09894237]]
# Output errors: [[ 0.09793216]]
# Output errors: [[ 0.10291678]]
# Output errors: [[ 0.10863765]]
# Output errors: [[ 0.10226082]]
# Output errors: [[ 0.09636681]]
# Output errors: [[ 0.10268703]]

# %%
for i in weight_changes:
    print(i)
    pass
# Out:
# [[ 0.04973     1.42467048  0.62817646 -1.39754487]]
# [[ 0.04674735  1.42214499  0.62324647 -1.40365488]]
# [[ 0.04374996  1.41975741  0.61845523 -1.40956263]]
# [[ 0.04074928  1.41731256  0.61366928 -1.41547007]]
# [[ 0.03825492  1.41544737  0.60957499 -1.42059333]]
# [[ 0.03632396  1.41411245  0.60631555 -1.4248077 ]]
# [[ 0.03374552  1.41222749  0.60231486 -1.42984771]]
# [[ 0.03144404  1.41045738  0.59852405 -1.43466649]]
# [[ 0.02865984  1.40820566  0.59422064 -1.44006874]]
# [[ 0.02629171  1.40625397  0.59030584 -1.44503657]]
# [[ 0.02455617  1.40499272  0.58734883 -1.44888739]]
# [[ 0.02242383  1.40339086  0.58392292 -1.45327716]]
# [[ 0.02016837  1.40154711  0.58026161 -1.45796464]]
# [[ 0.01763205  1.39957842  0.57642562 -1.46280227]]
# [[ 0.01646181  1.39880152  0.57439475 -1.46552354]]
# [[ 0.01550768  1.39824448  0.57279227 -1.46769747]]
# [[ 0.01432367  1.39750242  0.57086719 -1.47030794]]
# [[ 0.01282781  1.39646211  0.56845739 -1.47352585]]
# [[ 0.01175928  1.39572912  0.56660318 -1.47605169]]
# [[ 0.01043552  1.3948619   0.56448112 -1.47888942]]
# [[ 0.0091123   1.39386688  0.56221897 -1.48193386]]
# [[ 0.00792077  1.39310017  0.56033192 -1.48450083]]
# [[ 0.00631877  1.39205041  0.55792368 -1.48766567]]
# [[ 0.00515105  1.3912516   0.55606695 -1.49023931]]
# [[ 0.00365072  1.3901501   0.55366077 -1.49342925]]
# [[ 0.00219053  1.38900941  0.55127677 -1.49663995]]
# [[  1.05981639e-03   1.38824595e+00   5.49495478e-01  -1.49909017e+00]]
# [[ -4.42037261e-05   1.38747194e+00   5.47686788e-01  -1.50154877e+00]]
# [[ -1.14244764e-03   1.38669447e+00   5.45892837e-01  -1.50399595e+00]]
# [[-0.00255666  1.3856591   0.54368011 -1.50696013]]
# [[-0.00390691  1.38464913  0.54154056 -1.50984665]]
# [[-0.00466527  1.38414104  0.54030233 -1.51159747]]
# [[-0.00546493  1.38363931  0.53900354 -1.513355  ]]
# [[-0.00600799  1.38331604  0.53810928 -1.51459329]]
# [[-0.00726908  1.38235573  0.53607833 -1.51733341]]
# [[-0.00831312  1.38161703  0.53442723 -1.51960232]]
# [[-0.00899419  1.38115315  0.53329214 -1.5211923 ]]
# [[-0.01016474  1.38026792  0.53141124 -1.52374278]]
# [[-0.01153637  1.37927844  0.52936611 -1.52649646]]
# [[-0.01235004  1.37871666  0.52805813 -1.52830877]]
# [[-0.01306943  1.37825549  0.52694246 -1.52986859]]
# [[-0.01450309  1.37709771  0.52477577 -1.53285103]]
# [[-0.01566144  1.37630291  0.52306184 -1.53517244]]
# [[-0.01610536  1.37603963  0.52239156 -1.53614504]]
# [[-0.01653638  1.37577778  0.52171305 -1.53710882]]
# [[-0.01743012  1.37514577  0.52033782 -1.53903174]]
# [[-0.01793977  1.37482507  0.51952744 -1.5401626 ]]
# [[-0.01889045  1.3741679   0.51808732 -1.54214008]]
# [[-0.01931038  1.37389913  0.51740654 -1.54310104]]
# [[-0.01998636  1.37343648  0.51634035 -1.54459285]]
# [[-0.01465202  1.37708022  0.52707926 -1.5262589 ]]
# [[-0.00891024  1.38082785  0.53768916 -1.50874147]]
# [[-0.00372378  1.38463501  0.54830969 -1.49137361]]
# [[ 0.00190269  1.38927953  0.55809852 -1.47662654]]
# [[ 0.00707037  1.393391    0.56831868 -1.46078027]]
# [[ 0.01247866  1.39784545  0.57828735 -1.44642757]]
# [[ 0.01779901  1.40174313  0.58855967 -1.43132026]]
# [[ 0.0231801   1.40644371  0.59756693 -1.41937061]]
# [[ 0.02779828  1.41072002  0.6074308  -1.40560013]]
# [[ 0.0329953   1.41500426  0.6163754  -1.39371906]]
# [[ 0.03753916  1.41961887  0.62437445 -1.38352985]]
# [[ 0.04232313  1.42365714  0.63346892 -1.37154551]]
# [[ 0.04626693  1.42812982  0.6416447  -1.3611761 ]]
# [[ 0.05042545  1.43222057  0.65023099 -1.35037014]]
# [[ 0.05487014  1.43619207  0.65847522 -1.34021577]]
# [[ 0.05874415  1.44007649  0.66708235 -1.32954932]]
# [[ 0.06272594  1.44385545  0.67476687 -1.32050442]]
# [[ 0.0661914   1.44774619  0.68193391 -1.31228257]]
# [[ 0.0693822   1.45154389  0.68880314 -1.30414862]]
# [[ 0.07263538  1.45521796  0.69530877 -1.296828  ]]
# [[ 0.07613536  1.45859897  0.70236685 -1.28892618]]
# [[ 0.07926084  1.46206999  0.70897217 -1.28158167]]
# [[ 0.08192053  1.46544161  0.71500807 -1.27498017]]
# [[ 0.08449679  1.46868423  0.7207869  -1.2688873 ]]
# [[ 0.08715005  1.47189312  0.72679835 -1.26248689]]
# [[ 0.08971512  1.47501013  0.73276271 -1.25619749]]
# [[ 0.09194304  1.47803295  0.7382702  -1.25048102]]
# [[ 0.09421084  1.48090349  0.7437066  -1.244946  ]]
# [[ 0.09644028  1.48360648  0.74854334 -1.24013805]]
# [[ 0.0985667   1.4862571   0.75296508 -1.23570877]]
# [[ 0.10048933  1.48873141  0.75691512 -1.23181299]]
# [[ 0.10231717  1.49112198  0.76069117 -1.22811225]]
# [[ 0.10419721  1.49351151  0.76469196 -1.2242281 ]]
# [[ 0.10577952  1.49568291  0.76828165 -1.22087223]]
# [[ 0.10751154  1.49775863  0.77180108 -1.21763603]]
# [[ 0.10932891  1.49990165  0.77574316 -1.21401717]]
# [[ 0.11086073  1.50203102  0.77951261 -1.21052447]]
# [[ 0.11213497  1.50397873  0.78254152 -1.20768114]]
# [[ 0.11359095  1.50580984  0.78559235 -1.20492381]]
# [[ 0.11489499  1.50754837  0.78830455 -1.20244569]]
# [[ 0.11597964  1.50906989  0.79063244 -1.20037382]]
# [[ 0.11715577  1.51070722  0.79333685 -1.1979861 ]]
# [[ 0.1182945   1.51230147  0.79583095 -1.19573698]]
# [[ 0.11942699  1.5137814   0.79802377 -1.19373722]]
# [[ 0.12045633  1.51519283  0.80022665 -1.19180168]]
# [[ 0.12146157  1.51655776  0.80241419 -1.18990413]]
# [[ 0.1224453   1.51789521  0.80454482 -1.18805834]]
# [[ 0.12338498  1.51925906  0.80673876 -1.18614978]]
# [[ 0.12450942  1.52066116  0.80889424 -1.18420727]]
# [[ 0.12537885  1.52186327  0.81077739 -1.18258668]]
# [[ 0.13226985  1.5313283   0.82704756 -1.16983604]]
# [[ 0.13880157  1.54117076  0.84180152 -1.15841052]]
# [[ 0.14391105  1.55062122  0.85619815 -1.14804965]]
# [[ 0.14899222  1.55983956  0.86921542 -1.13912242]]
# [[ 0.15367989  1.56851674  0.88146068 -1.13135723]]
# [[ 0.15709107  1.57682136  0.89261129 -1.12475091]]
# [[ 0.16225592  1.58521838  0.90330993 -1.11795187]]
# [[ 0.16528941  1.59290041  0.91298128 -1.11252208]]
# [[ 0.16843884  1.60043476  0.92208549 -1.10742365]]
# [[ 0.17141305  1.60713403  0.93084657 -1.10327819]]
# [[ 0.17470051  1.61400665  0.93953015 -1.09881524]]
# [[ 0.17761012  1.62065096  0.9473936  -1.09483353]]
# [[ 0.1801964   1.62683396  0.95475953 -1.09139045]]
# [[ 0.18311068  1.6330429   0.96184517 -1.08797931]]
# [[ 0.18585642  1.63879432  0.96848505 -1.08510038]]
# [[ 0.18821828  1.64416863  0.97474261 -1.08251687]]
# [[ 0.19030997  1.64940793  0.98062813 -1.07999292]]
# [[ 0.19174537  1.65373234  0.98549243 -1.07830665]]
# [[ 0.19300014  1.65803407  0.99000549 -1.07673521]]
# [[ 0.19506851  1.66324631  0.99553731 -1.07421436]]
# [[ 0.19666677  1.66752749  1.00023452 -1.07256966]]
# [[ 0.19872463  1.67213278  1.00522753 -1.07061815]]
# [[ 0.19980879  1.67589484  1.00913137 -1.06932297]]
# [[ 0.20155498  1.68031045  1.01386551 -1.0674614 ]]
# [[ 0.20293588  1.6840384   1.0178586  -1.06615448]]
# [[ 0.20411882  1.68763573  1.02165405 -1.06489026]]
# [[ 0.20573697  1.69168548  1.02596079 -1.06328518]]
# [[ 0.20729066  1.69552057  1.03004069 -1.0618273 ]]
# [[ 0.20854149  1.69894789  1.03357236 -1.06071634]]
# [[ 0.20960919  1.70228536  1.03702953 -1.05957137]]
# [[ 0.21054991  1.70539786  1.04019778 -1.05861369]]
# [[ 0.21136872  1.70812712  1.04304732 -1.05785883]]
# [[ 0.21247498  1.71119039  1.04616382 -1.05696246]]
# [[ 0.2137084   1.71453658  1.04961103 -1.0557771 ]]
# [[ 0.21483511  1.71770307  1.05279844 -1.05471277]]
# [[ 0.21560783  1.72031104  1.05543769 -1.05404944]]
# [[ 0.21660456  1.72292459  1.05812352 -1.05338755]]
# [[ 0.21760829  1.7257005   1.06095659 -1.05257456]]
# [[ 0.21878833  1.72867002  1.06401712 -1.05163531]]
# [[ 0.21968139  1.7312663   1.06666226 -1.05093822]]
# [[ 0.22053321  1.73369076  1.06911023 -1.05035795]]
# [[ 0.22142412  1.73621422  1.07168486 -1.0497073 ]]
# [[ 0.22246338  1.73889484  1.07437091 -1.04894682]]
# [[ 0.22321049  1.74109509  1.07657667 -1.04845466]]
# [[ 0.22397116  1.74324629  1.07874124 -1.04799436]]
# [[ 0.22479568  1.74556964  1.08108027 -1.04743519]]
# [[ 0.22570934  1.74811312  1.08360795 -1.04673319]]
# [[ 0.22653714  1.75041813  1.08592471 -1.04615179]]
# [[ 0.22733455  1.75250318  1.08802752 -1.04569389]]
# [[ 0.228229    1.75481813  1.09035089 -1.04508662]]

# %%
def PlotWeights(weight_trail):
    # These are the colors that will be used in the plot
    color_sequence = ['#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c',
                  '#98df8a', '#d62728', '#ff9896', '#9467bd', '#c5b0d5',
                  '#8c564b', '#c49c94', '#e377c2', '#f7b6d2', '#7f7f7f',
                  '#c7c7c7', '#bcbd22', '#dbdb8d', '#17becf', '#9edae5']
    # Common sizes: (10, 7.5) and (12, 9)
    fig, ax = plt.subplots(1, 1, figsize=(12, 9))
    
    # Remove the plot frame lines. They are unnecessary here.
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    
    # Ensure that the axis ticks only show up on the bottom and left of the plot.
    # Ticks on the right and top of the plot are generally unnecessary.
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    
    fig.subplots_adjust(left=.06, right=.75, bottom=.02, top=.94)
    # Limit the range of the plot to only where the data is.
    # Avoid unnecessary whitespace.
    ax.set_xlim(0.0, 150.1)
    ax.set_ylim(-2.0, 2.0)
    
    # Make sure your axis ticks are large enough to be easily read.
    # You don't want your viewers squinting to read your plot.
    plt.xticks(range(0, 150, 5), fontsize=14)
    plt.yticks(range(-2, 2), fontsize=14)
    ax.xaxis.set_major_formatter(plt.FuncFormatter('{:.0f}'.format))
    ax.yaxis.set_major_formatter(plt.FuncFormatter('{:.0f}%'.format))
    
    # Provide tick lines across the plot to help your viewers trace along
    # the axis ticks. Make sure that the lines are light and small so they
    # don't obscure the primary data lines.
    plt.grid(True, 'major', 'y', ls='--', lw=.5, c='k', alpha=.3)
    
    # Remove the tick marks; they are unnecessary with the tick lines we just
    # plotted.
    plt.tick_params(axis='both', which='both', bottom='off', top='off',
                labelbottom='on', left='off', right='off', labelleft='on')
    
    # Now that the plot is prepared, it's time to actually plot the data!
    # Note that I plotted the majors in order of the highest % in the final year.
    majors = ['w11', 'w12', 'w13', 'w14']
    
    y_offsets = {'Foreign Languages': 0.5, 'English': -0.5,
             'Communications\nand Journalism': 0.75,
             'Art and Performance': -0.25, 'Agriculture': 1.25,
             'Social Sciences and History': 0.25, 'Business': -0.75,
             'Math and Statistics': 0.75, 'Architecture': -0.75,
             'Computer Science': 0.75, 'Engineering': -0.25}
    
    for rank, col in enumerate(majors):
        line = plt.plot(rank,
                    col[0][rank],
                    lw=2.5,
                    color=color_sequence[rank])

# %%
PlotWeights(weight_changes)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-72fee1c02680> in <module>()
# ----> 1 PlotWeights(weight_changes)
#
# <ipython-input-42-dc48b8b3836d> in PlotWeights(weight_trail)
#      62                     col[0][0],
#      63                     lw=2.5,
# ---> 64                     color=color_sequence[rank])
#
# IndexError: list index out of range

# %%
for rank, col in enumerate(weight_changes):
    print(rank, ":", col[0][3])
    pass
# Out:
# 0 : -1.39754487007
# 1 : -1.40365488254
# 2 : -1.40956262822
# 3 : -1.41547006599
# 4 : -1.4205933291
# 5 : -1.42480770353
# 6 : -1.42984771065
# 7 : -1.43466649294
# 8 : -1.44006873734
# 9 : -1.44503657154
# 10 : -1.44888738977
# 11 : -1.45327715701
# 12 : -1.45796464152
# 13 : -1.46280227175
# 14 : -1.46552353711
# 15 : -1.46769747088
# 16 : -1.47030793702
# 17 : -1.47352584627
# 18 : -1.47605168712
# 19 : -1.47888941639
# 20 : -1.48193385737
# 21 : -1.48450082509
# 22 : -1.48766567199
# 23 : -1.49023930758
# 24 : -1.49342924825
# 25 : -1.49663995108
# 26 : -1.49909017461
# 27 : -1.50154877027
# 28 : -1.50399594722
# 29 : -1.50696013363
# 30 : -1.50984664806
# 31 : -1.51159747216
# 32 : -1.51335500165
# 33 : -1.5145932931
# 34 : -1.51733341477
# 35 : -1.51960231669
# 36 : -1.52119229713
# 37 : -1.52374278383
# 38 : -1.52649646252
# 39 : -1.52830876788
# 40 : -1.52986858902
# 41 : -1.53285102552
# 42 : -1.53517243932
# 43 : -1.53614504036
# 44 : -1.53710882066
# 45 : -1.53903173551
# 46 : -1.54016260009
# 47 : -1.54214007521
# 48 : -1.54310104169
# 49 : -1.5445928536
# 50 : -1.52625889908
# 51 : -1.50874146679
# 52 : -1.49137360654
# 53 : -1.47662654381
# 54 : -1.46078026762
# 55 : -1.44642756668
# 56 : -1.43132025789
# 57 : -1.41937060904
# 58 : -1.40560013451
# 59 : -1.39371906397
# 60 : -1.38352985165
# 61 : -1.37154551127
# 62 : -1.36117609697
# 63 : -1.35037014303
# 64 : -1.34021577123
# 65 : -1.32954932007
# 66 : -1.32050441554
# 67 : -1.3122825657
# 68 : -1.30414862141
# 69 : -1.29682799997
# 70 : -1.28892618428
# 71 : -1.28158167418
# 72 : -1.27498017138
# 73 : -1.26888730217
# 74 : -1.2624868858
# 75 : -1.25619748907
# 76 : -1.25048102405
# 77 : -1.24494600281
# 78 : -1.24013804633
# 79 : -1.23570876924
# 80 : -1.23181299311
# 81 : -1.22811224759
# 82 : -1.22422809916
# 83 : -1.22087223316
# 84 : -1.21763602813
# 85 : -1.21401717
# 86 : -1.21052447054
# 87 : -1.20768114025
# 88 : -1.20492380718
# 89 : -1.20244569315
# 90 : -1.20037381993
# 91 : -1.19798610061
# 92 : -1.19573698001
# 93 : -1.19373721862
# 94 : -1.19180168085
# 95 : -1.18990413336
# 96 : -1.18805834033
# 97 : -1.18614977653
# 98 : -1.18420727471
# 99 : -1.18258668218
# 100 : -1.16983603845
# 101 : -1.15841052356
# 102 : -1.14804965213
# 103 : -1.1391224238
# 104 : -1.13135722598
# 105 : -1.12475090807
# 106 : -1.11795186571
# 107 : -1.11252207747
# 108 : -1.10742364559
# 109 : -1.10327818544
# 110 : -1.09881524474
# 111 : -1.09483352923
# 112 : -1.09139045066
# 113 : -1.08797930656
# 114 : -1.08510038357
# 115 : -1.08251686675
# 116 : -1.07999292414
# 117 : -1.07830665094
# 118 : -1.07673521117
# 119 : -1.0742143633
# 120 : -1.07256966218
# 121 : -1.07061815052
# 122 : -1.06932296721
# 123 : -1.06746139762
# 124 : -1.06615448371
# 125 : -1.06489025646
# 126 : -1.06328517714
# 127 : -1.06182730355
# 128 : -1.06071634018
# 129 : -1.05957137383
# 130 : -1.05861368517
# 131 : -1.05785882516
# 132 : -1.05696246098
# 133 : -1.05577709785
# 134 : -1.05471276912
# 135 : -1.05404944274
# 136 : -1.05338755445
# 137 : -1.05257455724
# 138 : -1.05163531117
# 139 : -1.05093821533
# 140 : -1.05035795172
# 141 : -1.04970729679
# 142 : -1.04894681643
# 143 : -1.04845465783
# 144 : -1.04799435772
# 145 : -1.04743518578
# 146 : -1.04673318589
# 147 : -1.04615179404
# 148 : -1.04569388567
# 149 : -1.0450866167
